# %%
import firebase_admin
from firebase_admin import credentials
from firebase_admin import firestore

cred = credentials.Certificate("dt-rasppi-firebase-adminsdk-fbsvc-2c475bf795.json")
firebase_admin.initialize_app(cred)

db = firestore.client()

# %%
db.collection("digital-twin").add({
    "temperature": 8.0,
    "humidity": 73.0,
    "timestamp": firestore.SERVER_TIMESTAMP
})

print("Berhasil mengirim data!")
# Out:
# Berhasil mengirim data!

# %%
docs = db.collection("digital-twin").stream()

for doc in docs:
    print(doc.id)
    print(doc.to_dict())
# Out:
# bVsSge9xNraB8RHgSc08
# {'humidity': 73.0, 'temperature': 8.0, 'timestamp': DatetimeWithNanoseconds(2026, 7, 6, 6, 21, 52, 413000, tzinfo=datetime.timezone.utc)}
# qBjQUaeH5gX35Z2pWGzz
# {'humidity': 75, 'temperature': 32, 'timestamp': DatetimeWithNanoseconds(2026, 7, 6, 6, 21, 13, 286000, tzinfo=datetime.timezone.utc)}
